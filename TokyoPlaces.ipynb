# %%
import numpy as np
import pandas as pd
import locale

# %%
df = pd.read_csv('./listings.csv')
df.head()
# Out:
# C:\Users\Jan\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (61,62) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#        id                          listing_url       scrape_id last_scraped  \
# 0   35303   https://www.airbnb.com/rooms/35303  20200322040935   2020-03-22
# 1  197677  https://www.airbnb.com/rooms/197677  20200322040935   2020-03-22
# 2  289597  https://www.airbnb.com/rooms/289597  20200322040935   2020-03-22
# 3  370759  https://www.airbnb.com/rooms/370759  20200322040935   2020-03-22
# 4  700253  https://www.airbnb.com/rooms/700253  20200322040935   2020-03-22
#
#                                                 name  \
# 0  La Casa Gaienmae C Harajuku, Omotesando is nearby
# 1                          Oshiage Holiday Apartment
# 2                  Private apt in central Tokyo #203
# 3  Cozy flat #203, local area YET 10 mins to shib...
# 4                  Private apt in central Tokyo #201
#
#                                              summary  \
# 0  This shared flat is locating at very close to ...
# 1                                                NaN
# 2                                                NaN
# 3  So close to busy centers, yet so peaceful! Jus...
# 4                                                NaN
#
#                                                space  \
# 0  This apartment is 3 bedroom flat shared with t...
# 1  We are happy to welcome you to our apartment, ...
# 2  ::::::::::::::::::::::::::::::::::::::::::::::...
# 3  Cozy and Relaxing, at home feeling in a reside...
# 4  ::::::::::::::::::::::::::::::::::::::::::::::...
#
#                                          description experiences_offered  \
# 0  This shared flat is locating at very close to ...                none
# 1  We are happy to welcome you to our apartment, ...                none
# 2  ::::::::::::::::::::::::::::::::::::::::::::::...                none
# 3  So close to busy centers, yet so peaceful! Jus...                none
# 4  ::::::::::::::::::::::::::::::::::::::::::::::...                none
#
#                                neighborhood_overview        ...          \
# 0  10 min walking to Harajuku ~ Urahara ~ Omotesa...        ...
# 1                                                NaN        ...
# 2                                                NaN        ...
# 3  Peaceful and residential area just 10 mins awa...        ...
# 4                                                NaN        ...
#
#   instant_bookable is_business_travel_ready          cancellation_policy  \
# 0                f                        f  strict_14_with_grace_period
# 1                f                        f                     moderate
# 2                f                        f  strict_14_with_grace_period
# 3                t                        f  strict_14_with_grace_period
# 4                f                        f  strict_14_with_grace_period
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             f                                f
# 1                             f                                f
# 2                             f                                f
# 3                             f                                f
# 4                             f                                f
#
#    calculated_host_listings_count  \
# 0                               3
# 1                               1
# 2                               2
# 3                               3
# 4                               2
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            2
# 1                                            1
# 2                                            2
# 3                                            3
# 4                                            2
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            1
# 1                                            0
# 2                                            0
# 3                                            0
# 4                                            0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0               0.18
# 1                                            0               1.59
# 2                                            0               1.19
# 3                                            0               1.40
# 4                                            0               1.14
#
# [5 rows x 106 columns]

# %%
cal = pd.read_csv('./calendar.csv')
cal.head()
# Out:
#    listing_id        date available       price adjusted_price  \
# 0     2645582  2020-03-22         f  $10,500.00     $10,500.00
# 1     2645582  2020-03-23         f  $10,500.00     $10,500.00
# 2     2645582  2020-03-24         f  $10,500.00     $10,500.00
# 3     2645582  2020-03-25         t  $10,500.00     $10,500.00
# 4     2645582  2020-03-26         t  $10,500.00     $10,500.00
#
#    minimum_nights  maximum_nights
# 0               2            1125
# 1               2            1125
# 2               2            1125
# 3               2            1125
# 4               2            1125

# %%
df['price_val'] = df.price.replace('[\$,]*','',regex=True).astype(float)
df['weekly_price_val'] = df.weekly_price.replace('[\$,]*','',regex=True).astype(float)
df['monthly_price_val'] = df.monthly_price.replace('[\$,]*','',regex=True).astype(float)

# %%
df.price_val.isnull().sum()
# Out:
# 0

# %%
df.groupby('host_id').price_val.mean()
# Out:
# host_id
# 151977        7571.666667
# 341577        4210.500000
# 771694       19751.125000
# 918551       15291.000000
# 961324        3546.000000
# 964081       10970.000000
# 1111228      15014.500000
# 1160146       7119.250000
# 1174369       9973.000000
# 1181399       5319.000000
# 1196132      19945.000000
# 1258947       9603.333333
# 1295685      29031.200000
# 1306308       9751.000000
# 1517461       3509.000000
# 1573631       7313.333333
# 1932364       5429.000000
# 2008948       4432.000000
# 2610437       6538.000000
# 2931434       7535.000000
# 3078284      19945.000000
# 3145185       4469.333333
# 3268251      20351.333333
# 3667176      23269.500000
# 4267866      59946.000000
# 4626879      16510.214286
# 4799233       4598.500000
# 4838043       5100.620690
# 4839990       5540.000000
# 4847803      13429.800000
#                  ...
# 337632629    15457.500000
# 337689088    20388.000000
# 337862134    10970.000000
# 338092010     6261.000000
# 338105829     4432.000000
# 338127923     3324.000000
# 338696128     5385.000000
# 338751685    17119.500000
# 338837535    17951.000000
# 338915770     7479.500000
# 339093164     9973.000000
# 339095271     9529.000000
# 339101354    70029.000000
# 339263512    11967.000000
# 339264560     5762.000000
# 339288076    11967.000000
# 339768828    26667.000000
# 339956773     7646.000000
# 339976431    13962.000000
# 340125585    19945.000000
# 340144167     8384.333333
# 340283854    36012.000000
# 340589680    15706.750000
# 340740878    29751.333333
# 340905589     5984.000000
# 341055885    19945.000000
# 341382455    17208.400000
# 341486623     4986.000000
# 341754858    69919.000000
# 341763186     4986.000000
# Name: price_val, Length: 3752, dtype: float64
